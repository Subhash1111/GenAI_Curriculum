# %% [markdown]
# # Week 12 — Capstone Project Scaffold
#
# **Goal:** Deliver an end‑to‑end project that combines ETL → EDA → ML/GenAI → Deployment/MLOps.
#
# This notebook provides a scaffold and checklists.

# %% [markdown]
# ## 1) Project charter

# %% [markdown]
# - Problem statement:
#
# - Target users & success metrics:
#
# - Data sources (APIs, files, warehouse):
#
# - Risks & constraints:

# %% [markdown]
# ## 2) Data engineering pipeline

# %%
# TODO: Implement extract() / transform() / load() functions
# from prefect import flow, task
# Use the ETL skeleton from Week 3

# %% [markdown]
# ## 3) EDA & feature plan

# %%
# Outline EDA questions & add visualizations (reuse Week 5 helpers)
# df = ...

# %% [markdown]
# ## 4) Modeling

# %%
# Baseline model (sklearn). Track metrics with MLflow.
# Optional: a small PyTorch model or Transformers pipeline.

# %% [markdown]
# ## 5) Deployment

# %%
# Export model; adapt Week 11 'fastapi_app.py' template.
# Add a /health endpoint and input schema validation.

# %% [markdown]
# ## 6) Governance & ethics checklist

# %% [markdown]
# - Data privacy: PII handling, anonymization
#
# - Bias & fairness tests on segments
#
# - Model monitoring: drift, performance, feedback loop
#
# - Incident response and rollback plan

# %% [markdown]
# ## 7) Presentation & handoff

# %% [markdown]
# - README with instructions
#
# - Demo video or screenshots
#
# - Future work & backlog
