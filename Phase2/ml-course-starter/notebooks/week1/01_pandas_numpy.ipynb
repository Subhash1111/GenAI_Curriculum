# %% [markdown]
# # Week 1: Pandas & NumPy

# %%
import numpy as np, pandas as pd
pd.set_option('display.max_columns', 100)
print('Ready!')
# Out:
# Ready!

# %% [markdown]
# ## Task
# Load a CSV into pandas, fix missing values, create 3 features, and describe the dataset.
