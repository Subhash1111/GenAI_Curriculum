# %% [markdown]
# # Supervised vs Unsupervised Learning
# *A practical exploration of two fundamental paradigms in Machine Learning*
#
# ---
#
# ## 🎯 Learning Goals
# - Understand the conceptual difference between supervised and unsupervised learning
# - See examples of both types in code
# - Know which algorithms belong to each category
# - Learn where to apply them in real-world scenarios

# %% [markdown]
# ## 1️⃣ What is Supervised Learning?
#
# Supervised learning is when the model is **trained on labeled data** — i.e., each example has both input features and the correct output (label).
# The goal is to **learn a mapping from inputs → outputs**, then generalize to unseen data.
#
# **Examples:**
# - Predicting house prices (regression)
# - Classifying emails as spam or not (classification)
# - Forecasting demand (regression)
#
# ### 🧠 Analogy
# Think of supervised learning as a **teacher–student** setup: the teacher provides the correct answers during training.
#
# ### 🧩 Typical use cases
# | Task | Description | Example |
# |------|--------------|----------|
# | **Classification** | Predict a category | Spam detection, sentiment analysis |
# | **Regression** | Predict a continuous value | Sales forecasting, price estimation |
# | **Forecasting** | Predict future numeric trends | Stock prices, weather |
# | **Anomaly Detection (labeled)** | Detect outliers given normal data | Credit card fraud detection |

# %% [markdown]
# ## 2️⃣ What is Unsupervised Learning?
#
# Unsupervised learning works on **unlabeled data** — the model discovers **hidden patterns or structures** without knowing the “correct” output.
#
# **Examples:**
# - Grouping customers into segments (clustering)
# - Reducing high-dimensional data for visualization (dimensionality reduction)
# - Finding associations in market-basket data (association rules)
#
# ### 🧠 Analogy
# It’s like being an explorer with no map — the algorithm finds structure and patterns **on its own**.
#
# ### 🧩 Typical use cases
# | Task | Description | Example |
# |------|--------------|----------|
# | **Clustering** | Group similar data points | Customer segmentation, document grouping |
# | **Dimensionality Reduction** | Simplify data while keeping variance | PCA for feature extraction |
# | **Association Rule Mining** | Find co-occurrence patterns | Market basket analysis |
# | **Anomaly Detection (unsupervised)** | Identify rare events without labels | Network intrusion detection |

# %% [markdown]
# ## 3️⃣ Comparison Summary
#
# | Aspect | Supervised Learning | Unsupervised Learning |
# |--------|---------------------|------------------------|
# | **Training Data** | Labeled | Unlabeled |
# | **Goal** | Predict outcome | Discover structure |
# | **Feedback** | Learns from correct labels | No feedback, self-organized |
# | **Output** | Known target (y) | Hidden pattern / cluster |
# | **Examples** | Regression, Classification | Clustering, PCA |

# %% [markdown]
# ## 4️⃣ Common Algorithms under Each Category
#
# ### 🟢 **Supervised Learning Models**
# | Type | Algorithm | Description / Example |
# |------|------------|-----------------------|
# | **Linear Models** | Linear Regression | Predict continuous values (e.g., sales, housing prices) |
# | | Logistic Regression | Binary or multi-class classification (e.g., spam detection) |
# | **Tree-based Models** | Decision Tree | Splits data into rules for prediction |
# | | Random Forest | Ensemble of trees to improve accuracy and reduce overfitting |
# | | Gradient Boosting (XGBoost, LightGBM) | Sequentially improves weak learners |
# | **Distance-based** | K-Nearest Neighbors (KNN) | Classifies by majority of nearest neighbors |
# | **Probabilistic** | Naive Bayes | Uses Bayes' theorem for text and spam filtering |
# | **Support Vector Machines** | SVM | Finds best separating hyperplane between classes |
# | **Neural Networks** | MLP, Deep Learning | Flexible non-linear learners for complex data |
#
# ### 🔵 **Unsupervised Learning Models**
# | Type | Algorithm | Description / Example |
# |------|------------|-----------------------|
# | **Clustering** | K-Means | Groups data by similarity (e.g., customer segments) |
# | | Hierarchical Clustering | Tree-like grouping structure |
# | | DBSCAN | Density-based clustering for irregular shapes |
# | **Dimensionality Reduction** | PCA (Principal Component Analysis) | Reduce features while retaining variance |
# | | t-SNE, UMAP | Visualize high-dimensional data in 2D/3D |
# | **Association Rule Mining** | Apriori, FP-Growth | Discover frequent itemsets (e.g., market baskets) |
# | **Autoencoders (Neural)** | Deep unsupervised representation learning | Feature extraction or anomaly detection |

# %% [markdown]
# ## 5️⃣ Example: Supervised Learning (Classification)
#
# We'll train a simple **Decision Tree Classifier** to predict species in the Iris dataset.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score

# Load data
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(
    iris.data, iris.target, test_size=0.3, random_state=42)

model = DecisionTreeClassifier(max_depth=3, random_state=0)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# ## 6️⃣ Example: Unsupervised Learning (Clustering)
#
# We'll use **K-Means** to discover natural groups in the Iris dataset — without using the labels.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

X = iris.data
kmeans = KMeans(n_clusters=3, random_state=0)
labels = kmeans.fit_predict(X)

plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=labels)  # no explicit colors
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Unsupervised Clustering (K-Means on Iris)')
plt.show()

# %% [markdown]
# ## 7️⃣ Real-World Applications
#
# | Domain | Supervised Example | Unsupervised Example |
# |---------|-------------------|----------------------|
# | Finance | Predict credit default | Segment customers by spending behavior |
# | Marketing | Predict ad click-through | Cluster customers for campaigns |
# | Healthcare | Predict disease outcome | Group similar patient profiles |
# | Manufacturing | Predict machine failure | Detect abnormal sensor readings |
# | Retail | Predict sales | Market basket analysis |

# %% [markdown]
# ## 8️⃣ Key Takeaways
# - **Supervised** = learn from *labeled* data (predict known outcomes).
# - **Unsupervised** = learn from *unlabeled* data (discover hidden patterns).
# - Both are essential: supervised for prediction, unsupervised for exploration.
# - In practice, we often combine both (e.g., pretrain with unsupervised → fine-tune with supervised).
#
# **Next notebook suggestion:** *Data_Insights_and_EDA.ipynb* — we'll explore exploratory data analysis and discovery before modeling.
